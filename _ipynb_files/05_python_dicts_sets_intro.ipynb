# %% [markdown]
# # Dict (Dictionary)
#
# Similar to actual dictionaries
#
# Dictionaries can be thought of as being composed of two lists combined – a list of keys and a list values:
#
# |   keys  |    values   |
# |:-------:|:-----------:|
# |   one   |     uno     |
# |   two   |     dos     |
# |  three  |    tres     |
# |  four   |   cuatro    |
# |  five   |   cinco     |

# %%
# Declare a list with English number words
numbers = ["one", "two", "three", "four", "five"]

# Declare a dictionary mapping English numbers to Spanish numbers
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

# Print the spanish_numbers_dict
print( spanish_numbers )

# Print the spanish for two
print( spanish_numbers["two"] )

# %%
spanish_numbers = {
    12: "uno",
    22: "dos",
    32: "tres",
    42: "cuatro",
    51: "cinco"
}
spanish_numbers[0]

# %%
numbers = ["one", "two", "three", "four", "five"]
print( numbers[3] )

# %%
# keys can be anything that can be hashable
# i.e. loosely: "if it can't change it can be a key"

# here using tuples
spanish_numbers = {
    (1, "one"): "1, uno",
    (2,"two") : "2, dos",
    (3,"three"): "3, tres",
    (4,"four"): "cuatro",
    (5,"five"): "cinco"
}
spanish_numbers[(3,"three")]

# %%
#trying to key on a list
#Error

spanish_numbers = {
    [1, "one"]: "1, uno" 
}

# %%
nums = {
         1: "uno"
        ,1: "one" 
}

nums[1] #two keys same (not recommended) need unique

# %%
nums = {
         "one": "unosaldafjlfjdaskjfaldfjadslfjadsljfaljdfsaljfaldjsflasjflasjdf;lajskfdl"
        ,"two": "two" 
}

nums2 = {
         "one": "unosaldafjlfjdaskjfaldfjadslfjadsljfaljdfsaljfaldjsflasjflasjdf;lajskfdl"
        ,"two": "two" 
}

print(id(nums), id(nums["one"]), nums["one"])
print(id(nums2), id(nums2["one"]), nums2["one"])

# %%
#Python 3.6: 'order' was introduced into dictionaries
#  prior to that NO concept of order
#  after 'insertion order'

# %%
spanish_numbers = {
    "one": "uno",
    "five": "cinco",
    "three": "tres",
    "four": "cuatro",
    "two" : "dos",
}

print(spanish_numbers.popitem())
print(spanish_numbers.popitem())
print('at end: ')
print(spanish_numbers)

# %%
spanish_numbers = {
    "one": "uno",
    "five": "cinco",
    "three": "tres",
    "four": "cuatro",
    "two" : "dos",
}

#CAN'T index into a dict with a number-index

# spanish_numbers[1] #error

# %%
spanish_numbers = {
    34: "uno",
    27: "cinco"
}
spanish_numbers[34]

# %%
#  Dict: keys, values and items
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

# print( spanish_numbers.keys() )
numbers_view = spanish_numbers.items()

print(numbers_view)

# %%
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}
spanish_numbers["six"]= "seis"
print(spanish_numbers)

# %%
spanish_numbers = {'one': 'uno', 'two': 'dos', 'three': 'tres', 'four': 'cuatro', 'five': 'cinco', 'six': 'seis'}

spanish_numbers["two"] = "DOS"

spanish_numbers

# %%
print( spanish_numbers.values() )

# %%
print( spanish_numbers.items() )

# %%
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

print( spanish_numbers.get("tree", "default value") )

# %%
# We can add new values by just assigning to them
# NOTE: if the key already exists, the value will be overwritten
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

print(f"before: {spanish_numbers}")
spanish_numbers["two"] = "dos actualizado"      
print(f" after: {spanish_numbers}")

# %%
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

print(f"before: {spanish_numbers}")
spanish_numbers["six"] = "seis"                 
print(f" after: {spanish_numbers}")

# %% [markdown]
# #### dict pop()

# %%
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

print(f"before: {spanish_numbers}")
removed_value = spanish_numbers.pop("four")     
print(f" after: {spanish_numbers}")

# %%
print(removed_value)

# %%
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

spanish_numbers.pop()   #error: requires argument
spanish_numbers

# %% [markdown]
# # Dictionary properties:
#
# - Values are mapped to keys
# - Values are accessed by their corresponding key
# - Key are unique and are immutable
# - Multiple keys can have the same values, values can be anything (including mutable types like lists)
# - Values cannot exist without a key

# %%
my_dict = dict()

print( my_dict, type(my_dict) )

# %%
my_dict = {}

a_list = [1,2,3]
a_list.remove(2)   
print(a_list)

# %%
# recall...

my_dict = {}
a_list = [1,2,3]   #immutable OK for key

my_dict[ a_list ] = " some value "
my_dict


#TASK: try above with: a_list as a list '[]'

# %%
my_dict = {}
a_tup = (1,['a','b'],3)   #not OK tuple with 'mutable' element

my_dict[ a_tup ] = "one,two,three"
my_dict

# %%
# Note that trying to access a key that doesn't exist will raise an error:
# spanish_numbers["eight"]  # raises KeyError
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

test = spanish_numbers["eight"]   #uncomment and see error

# %%
# get('key') to prevent a KeyError....
spanish_numbers = {
    "one": "uno",
    "two": "dos",
    "three": "tres",
    "four": "cuatro",
    "five": "cinco"
}

test = spanish_numbers.get('eight')
print(test)

# %%
#get('key', 'default'): default-value: value you want back in case it doesn't exist
test = spanish_numbers.get('eight', 'not found')
test

# %%
# The dict `.get()` method can be used to prevent a key error
#   by providing a default value in the case the key doesn't exist

check = "eight"
returned = spanish_numbers.get("eight", "search term  not found!") #no KeyError (crash)
print( returned )

# %%
# If we use the `.get()` method without a default value ( it defaults to None)
print(spanish_numbers.get("eight"))

# %% [markdown]
# #### creating dictionaries... example Lunar New Year

# %%
#Example:
# e.g. two same length lists
years   = [2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035]
animals = ['Dragon', 'Snake', 'Horse', 'Goat', 'Monkey', 'Rooster', 'Dog', 'Pig', 'Rat', 'Ox', 'Tiger', 'Rabbit']

print( len(years), len(animals))  # will print 12, 12 (e.g. same length)


# create a dict of lunar new years: year=>animal
# _one_ way...

animal_calendar = {}                 #create dict

for i in range(len(years)):         #loop to fill
    year    = years[i]
    animal  = animals[i]

    animal_calendar[year] = animal

print(animal_calendar)

# %%
# it works...
print ("2023: the year of the : ", animal_calendar[2026])
print ("2028: the year of the : ", animal_calendar[2031])

# %%
#another way:
# part 1: zip
years   = [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
animals = ['Rabbit', 'Dragon','Snake','Horse', 'Goat', 'Monkey', 'Rooster', 'Dog', 'Pig', 'Rat', 'Ox', 'Tiger']

# recap zip() function
zipped = zip(years, animals)
#zip
#loop over zipped
for item in zipped:
    print(item)

# %%
#part 2: dict()
print( type( {} ) )  #type of an empty dict

# %%
# exploring dict type with 
#  dir() and help()
# dir(dict)
help(dict.fromkeys)

# %%
test = 'abc'
new_dict = dict.fromkeys(test, 0)
new_dict

# %%
my_dict = {1:'a', 2:'b'}
new_dict = dict.fromkeys(my_dict, 0)

print( id(my_dict), my_dict)
print( id(new_dict), new_dict)

# %%
my_dict = dict()
print( my_dict, type(my_dict) )

# %%
a =[2023, 2024, 2025]
b = ['Rabbit', 'Dragon','Snake']
zipped = list(zip(a, b))

zipped

# new_dict = dict( zipped )  #list of tuples
aa = [1,2,3]
bb = ['a', 'b', 'c']


new_dict = dict( [(1, 'a'), (2, 'b'), (3, 'c')] )
new_dict

# %%
# Using above...
years   = [2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
animals = ['Rabbit', 'Dragon','Snake','Horse', 'Goat', 'Monkey', 'Rooster', 'Dog', 'Pig', 'Rat', 'Ox', 'Tiger']

# using dict() and zip() combined
animal_calendar = dict( zip(years, animals) )
print(animal_calendar)
search_year = 2026
print(f"{search_year} is the year of the  {animal_calendar.get(search_year, 'year not found')}" )

# %%
animal_calendar = {
    2023: 'Rabbit', 
    2024: 'Dragon', 
    2025: 'Snake', 
    2026: 'Horse',
} 

animal_calendar.update( {2027:'Goat', 2028:'Monkey'} )
animal_calendar

# %%
#the .update( :dict )
animal_calendar = {2023: 'Rabbit', 2024: 'Dragon', 2025: 'Snake', 2026: 'Horse'} 
print(f"before: {animal_calendar=}")
animal_calendar.update( {2027: 'Goat', 2028: 'Monkey', 2029: 'Rooster', 2030: 'Dog'} )
print(f" after: {animal_calendar=}")

# %%
#the .update() - adding an entry with a single dict-item as a dict itself

animal_calendar = {2023: 'Rabbit', 2024: 'Dragon', 2025: 'Snake', 2026: 'Horse'} 
# animal_calendar[2029] = "Rooster"
animal_calendar.update( {2029 : 'Rooster'} )

print(animal_calendar)

# %%
animal_calendar = {2023: 'Rabbit', 2024: 'Dragon', 2025: 'Snake', 2026: 'Horse'} 
print(f"before: {animal_calendar=}")
animal_calendar[ 2022 ] = 'Salmon'
print(f" after bad insert: {animal_calendar=}")

# %%
# Example of .pop( ) on a Lunar New Year dict
#
animal_calendar = {2023: 'Rabbit', 2024: 'Dragon', 2025: 'Snake', 2026: 'Horse'} 
print(f"before: {animal_calendar=}")
animal_calendar[ 2022 ] = 'Salmon'
print(f" after bad insert: {animal_calendar=}")

print("\n\n",'*'*50)
print("removing: joke value")
popped_value = animal_calendar.pop(2022)
print(f" after pop: {animal_calendar=}")
print ( popped_value )


#TASK: 
#What else can we do:
# dir(dict) # uncomment, run and explore with help(dict.popitem), for example

# %%
# about dict and popitem()
animal_calendar = {2023: 'Rabbit', 2024: 'Dragon', 2025: 'Snake', 2026: 'Horse'} 

print(len(animal_calendar))

print( animal_calendar.popitem() )
print( animal_calendar.popitem() )

## See below link: for interest/knowledge: from Python 3.7
##https://stackoverflow.com/questions/60848/how-do-you-retrieve-items-from-a-dictionary-in-the-order-that-theyre-inserted

# %%
#A nicer print than the default with
# for key, value ... items()

lunar_new_year = {2023: 'Rabbit', 2024: 'Dragon', 2025: 'Snake', 2026: 'Horse'} 

print(lunar_new_year)
for year, animal in lunar_new_year.items():
    print(f"{year}: {animal}")

#compare to print( dict ) output

# %%
#could also use something like pprint...
from pprint import pprint

data = {
    "name": "Alice",
    "age": 30,
    "skills": ["Python", "SQL", "Docker"],
    "active": True
}

print(data)
print()
pprint(data)

# %%
#What else can we do:
# dir(dict) # uncomment, run and explore with help(dict.fromkeys), for example
dir(dict)
help(dict.fromkeys)

# %%
# Example: part1: string
import string
# dir(string)
print( string.ascii_lowercase )

# %%
# Example: part2: dict.fromkeys()
a_list = [1,2,3]
result = dict.fromkeys(a_list, 0)
print(result)

# %%
# TASK:
# Example: count of all letters in a text
import string

#create a dict with 
#   a) all letters of alphabet as keys
#   b) values set to zero for each

new_dict = dict.fromkeys(string.ascii_lowercase, 0)
print(new_dict)
# sample text
text = "abba ace"

for character in text:
    if character == ' ':
        continue
    else:
        new_dict[character] += 1


#use the dict to store a count of
#   all letters in the text

# for character in text:
#     if  new_dict.get(character) != None:
#         print('character', character, 'exists')
#         new_dict[character] += 1
#     else:
#         print("not in dict: that's the space")

new_dict

# %%
#CHALLENGE:
# Imagine dict of questions/answers
""" 
{
        'questions':
                    {
                        "question" : "answer",
                        "question" : "answer"
                    },
        'invalidQuestions': 
                    {
                        "question" : "answer",
                        "question" : "answer"
                    }
    }
"""

question_bank = {
             "questions": { "q1":"q1answer",   "q2":"q2answer" }
    ,"invalid_questions": {"eq1":"eq1answer", "eq2":"eq2answer" }
}

invalid_questions = question_bank['invalid_questions']
q2_answer = invalid_questions['eq2']
print( q2_answer )

print( question_bank["questions"]["q1"] )

# how to add to questions / invalid-questions...

# %% [markdown]
# # Sets
# Sets are like lists, but where the order doesn't matter.
#
# Without order, we cannot index or slice a set at all.
#
# This also means there cannot be duplicates - adding the same value a second time will be ignored.

# %%
nums = {1, 3, 5, 2, 3, 5, 1, 6}
nums[1]  #index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 nums = {1, 3, 5, 2, 3, 5, 1, 6}
# ----> 2 nums[1]  #index
#
# TypeError: 'set' object is not subscriptable

# %%
num_list = {1 , 3 , 5 , 2, 3}
num_list
for num in num_list:
    print(num)
# Out:
# 1
# 2
# 3
# 5

# %%
num_set = {1 , 3 , 5 , 2, 3}

7 not in num_set
# Out:
# True

# %%
num_dict = { 1:'a' , 2:'b' , 3:'c'}  #dict: items separated 'key:value'

# %%
s = set()
s.add(7)
s
# Out:
# {7}

# %%
nums = [1, 3, 5, 2, 3, 5, 1, 6]
num_set = set(nums)                 #no duplicates
print(num_set)
print(nums)
# Out:
# {1, 2, 3, 5, 6}
# [1, 3, 5, 2, 3, 5, 1, 6]

# %%
#another way using '{' and '}'
my_set = {"a", "a", "b", "c"}
my_set
# Out:
# {'a', 'b', 'c'}

# %%
#try indexing...
my_set[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 #try indexing...
# ----> 2 my_set[1]
#
# TypeError: 'set' object is not subscriptable

# %%
list_ = ["a", "b", "c"]
list_[1]

# %%
s = set()
dir(s)
# help(set.remove)
# help(set.pop)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %%
help( set.remove )
# Out:
# Help on method_descriptor:
#
# remove(self, object, /) unbound builtins.set method
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
def robs_remove( a_list, element_to_remove ):
    index = a_list.index(element_to_remove)
    value_removed = a_list[index]
    del a_list[index]


l = ["a", "b", "a", "c" ]   #"c"[value_removed]
removed = robs_remove(l, 'c')

print(l)
print('removed this: ', removed)
# Out:
# ['a', 'b', 'a']
# removed this:  None

# %%
# what does remove return
l = ["a", "b", "a", "c"]
s = set(l)
remove_thing = 'x'

try:
    s.remove(remove_thing)
    print( 'I removed: ', remove_thing)
    print(s)
except KeyError as error:
    print( "something went wrong", type(error), error)

print('program continues...')
# Out:
# something went wrong <class 'KeyError'> 'x'
# program continues...

# %%
s = {"a", "b", "a", "c"}
if 'c' in s:
    s.remove("c")
    
print(s)
# Out:
# {'b', 'a'}

# %%
help(set.discard)
# Out:
# Help on method_descriptor:
#
# discard(self, object, /) unbound builtins.set method
#     Remove an element from a set if it is a member.
#
#     Unlike set.remove(), the discard() method does not raise
#     an exception when an element is missing from the set.

# %%
s = {"a", "b", "a", "c"}
print(s)
returned = s.discard("x")
print(s)
# Out:
# {'c', 'b', 'a'}
# {'c', 'b', 'a'}

# %%
help( s.pop )
# Out:
# Help on built-in function pop:
#
# pop() method of builtins.set instance
#     Remove and return an arbitrary set element.
#
#     Raises KeyError if the set is empty.

# %%
#what does pop return
s = {"a", "b",  "d",  "c"}
element = s.pop()
element, s
# Out:
# ('c', {'a', 'b', 'd'})

# %%
nums = [1, 3, 5, 2, 3, 5, 1, 6]
num_set = set(nums)
print(num_set)

print( len(num_set)) 
num_set.remove(5)
print( len(num_set))
# Out:
# {1, 2, 3, 5, 6}
# 5
# 4

# %%
nums = [1, 3, 5, 2, 3, 5, 1, 6]
num_set = set(nums)
print(num_set)


while len(num_set) > 0:
    popped = num_set.pop()
    print(popped, num_set)

print("removed all set elements")
# Out:
# {1, 2, 3, 5, 6}
# 1 {2, 3, 5, 6}
# 2 {3, 5, 6}
# 3 {5, 6}
# 5 {6}
# 6 set()
# removed all set elements

# %%
some_text = "Under the shade of the willow tree."
for char in some_text:
    print(char, '-', end=" ")
# Out:
# U - n - d - e - r -   - t - h - e -   - s - h - a - d - e -   - o - f -   - t - h - e -   - w - i - l - l - o - w -   - t - r - e - e - . -

# %%
some_text = "Under the shade of the willow tree."
set_text = set(some_text)
print( set_text )
# Out:
# {'o', 'w', 's', 'd', 'n', 'e', 'a', ' ', 'U', 'i', 'l', '.', 'h', 't', 'r', 'f'}

# %%
help(set.add)

# %%
# We create sets similarly to lists, but with curly braces (just like dicts):
fruits = {"apple", "banana", "apricot"}

# We can add an item with `.add()`:
fruits.add("mango")
print(fruits)
# Out:
# {'banana', 'mango', 'apricot', 'apple'}

# %%
fruits = {'banana', 'mango', 'apricot', 'apple'}
# Quiz - what would happen if we repeat this?
print(fruits)
fruits.add("mango")
print(fruits)
# Out:
# {'banana', 'apricot', 'mango', 'apple'}
# {'banana', 'apricot', 'mango', 'apple'}

# %%
help(set.remove)
# Out:
# Help on method_descriptor:
#
# remove(self, object, /) unbound builtins.set method
#     Remove an element from a set; it must be a member.
#
#     If the element is not a member, raise a KeyError.

# %%
dir(set)

# %%
help(set.discard)

# %%
fruits = {"apple", "banana", "apricot", "manga"}
print( fruits.remove("manga") )
fruits
# Out:
# None
# {'apple', 'apricot', 'banana'}

# %%
fruits = {"apple", "banana", "apricot", "manga"}
print(fruits)
fruits.remove("manga")
fruits.add("mango")
print(fruits)
# Out:
# {'banana', 'manga', 'apricot', 'apple'}
# {'banana', 'apricot', 'apple', 'mango'}

# %%
# We can remove an item with `.remove()`
fruits = {"apple", "banana", "apricot", "mango"}

fruits.remove("mango")
# print( fruits.remove("mango") )  #returns None

print(fruits)

# %% [markdown]
# #### `.remove()` VS `.discard()`

# %%
#Compare .remove()
fruits = {"apple", "banana", "apricot"}
# fruits.remove("mango")

# %%
# with .discard() 
fruits = {"apple", "banana", "apricot"}
fruits.discard("mango") #no key error

# %%
# do a help(set.discard) and a help(set.remove)
# help(set.discard)
# help(set.remove)

# %% [markdown]
# #### set membership with `in`

# %%
# 'membership' of a set with `in`
# a set: 'fruits'
fruits = {"apple", "orange", "banana", "grape"}

# Check if "apple" and "cucumber" are in the set
print(   "apple" in fruits)     # True
print("cucumber" in fruits)     # False
# Out:
# True
# True

# %% [markdown]
# #### set `update()` with another set or iterable

# %%
x = {1,2,3,4}
y = {2,4,6,8}
print(f"x: start: {x}")
print(id(x), x)
print(".update() updates the current set adding <no-duplicates> ")
x.update(y)
print(f"x: after: {x}")
print(id(x), x)
# Out:
# x: start: {1, 2, 3, 4}
# 1946393973856 {1, 2, 3, 4}
# .update() updates the current set adding <no-duplicates>
# x: after: {1, 2, 3, 4, 6, 8}
# 1946393973856 {1, 2, 3, 4, 6, 8}

# %%
# Also works with any other iterable.
x = {1,2,3,4}
x.update("abcd")
print(x)
# Out:
# {1, 2, 3, 4, 'c', 'd', 'b', 'a'}

# %%
dir(set)
# Out:
# ['__and__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iand__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__isub__',
#  '__iter__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__ror__',
#  '__rsub__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__xor__',
#  'add',
#  'clear',
#  'copy',
#  'difference',
#  'difference_update',
#  'discard',
#  'intersection',
#  'intersection_update',
#  'isdisjoint',
#  'issubset',
#  'issuperset',
#  'pop',
#  'remove',
#  'symmetric_difference',
#  'symmetric_difference_update',
#  'union',
#  'update']

# %% [markdown]
# #### union and intersection with `|` and `&`
# > but do a `dir(set)` also

# %%
# Sets in Python are modelled after sets in maths, and support the union and intersection operations:
small_integers = {1, 2, 3, 4}
even_integers  = {2, 4, 6, 8}

union = small_integers | even_integers  # Note the pipe symbol
print(union)  # The union is the set of elements in EITHER of the two original sets

intersection = small_integers & even_integers  # Note the ampersand (and) symbol
print(intersection)  # The intersection is the set of elements in BOTh of the two original sets
# Out:
# {1, 2, 3, 4, 6, 8}
# {2, 4}

# %%
small_integers = {1, 2, 3, 4}
even_integers  = {2, 4, 6, 8}

small_integers.difference( even_integers )
# Out:
# {6, 8}

# %%
# dir(set)

# %%
#What else can we do:
# dir(set) # uncomment, run and explore with help(set.update), for example
help(set.difference)
# Out:
# Help on method_descriptor:
#
# difference(self, /, *others) unbound builtins.set method
#     Return a new set with elements in the set that are not in the others.

# %%
s = {"a", "b", "c"}
t = {"a", "b"}

print( t.issubset(s)  )   #True
print( s.issuperset(t) ) #True
s.difference(t)
# Out:
# True
# True
# {'c'}

# %%
s = { 7 }
t = {"7"}

s.difference(t)
# Out:
# {7}
