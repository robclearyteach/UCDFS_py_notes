# %%
import time
# help(time.time)
# dir(time)
time_seconds = time.time()
print( time_seconds )
# Out:
# 1766083834.603475

# %%
from datetime import datetime
# help(datetime)
# dir(datetime)
print( datetime.today() )
print( datetime.now()   )
# Out:
# 2025-12-18 18:51:00.502332
# 2025-12-18 18:51:00.503045

# %%
#example of a basic timer...
import time
start_time = time.time()             #set start timer

for _ in range(5):
    print("tick...")
    time.sleep(1)                   #pause for 1 sec (five times)

end_time = time.time()               #stop the timer

time_taken = end_time - start_time  #calc time elapsed
print(f"time taken: {time_taken}")
# Out:
# tick...
# tick...
# tick...
# tick...
# tick...
# time taken: 5.017446517944336

# %%
import time
help(time.perf_counter)
# Out:
# Help on built-in function perf_counter in module time:
#
# perf_counter()
#     perf_counter() -> float
#
#     Performance counter for benchmarking.

# %%
#TASK: Write code to time this loop
# See: time.perf_counter() VS time.time()
import time
start = time.perf_counter()
total_sum = 0
for i in range(1, 1990000):
    total_sum += i
end  = time.perf_counter()

time_taken = end - start
print(f"Took {time_taken} seconds to run")
# Out:
# Took 0.8242001999169588 seconds to run
