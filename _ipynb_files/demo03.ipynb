# %%
import time

now = time.time()
print(now)
# Out:
# 1765306582.531217

# %%
seconds = 144
# ho to get minutes?
minutes = seconds / 60
print("minutes:", minutes)
# Out:
# minutes: 2.4

# %%
#improve on that: want a whole number like '2' minutes
# convert to whole-number
import math
minutes = math.floor(seconds / 60)
print("minutes:", minutes)
# Out:
# minutes: 2

# %%
seconds = 144
# 2 minutes: but now
# how to get the remaining seconds 24
minutes = seconds // 60
seconds = seconds % 60

print( f"{minutes}:{seconds}" )
# Out:
# 2:24

# %%
#TASK: €1.44 - how many cents in that...
amount = 1.44

cents = amount * 100
print(f"There are {cents} cents in €{amount}")
# Out:
# There are 144.0 cents in €1.44

# %%
#how many 50cent coins in that?
amount = 1.44
cents = amount * 100

fifty_cent = 50

number_coins = cents // 50
# Out:
# 2.0

# %%
cents = 164
#Give 1euro coins and change:

euro_coins = cents // 100
remaining_amount = cents % 100

fifty_cents = remaining_amount // 50
remaining_amount = remaining_amount % 50
# Out:
# 14

# %%
#give change in euro, 
# and 50 cent and then 
# state the remainder
amount = 2.94
amount  = amount * 100          #change to cents           

euro        = 100
fifty_cent  = 50
twenty_cent = 20

euro_coins = amount // euro
remaining_amount = amount % euro 
#fifty-cent coins
fifty_cent_coins = remaining_amount // fifty_cent
remaining_amount = remaining_amount %  fifty_cent
#twenty-cent coins
twenty_cent_coins = remaining_amount // twenty_cent
remaining_amount =  remaining_amount %  twenty_cent
#next one...
remaining_amount
# Out:
# 4.0

# %%
### Previously: getting hours/min/sec 
# from seconds elapsed since 1/1/1970 (epoch) 
import time

# Get the current time in seconds since the epoch
now = time.time()
now = int(now)  #don't need factions of seconds
seconds_since_epoch = now
print( f"{seconds_since_epoch=}")

# Calculate total seconds in a day
seconds_in_a_day = (60 * 60) * 24 
print(f"{seconds_in_a_day=}")

# Find the number of seconds that have passed today
seconds_today =  seconds_since_epoch % seconds_in_a_day
print(f"{seconds_today=}")
seconds_in_an_hour = 60 * 60
# Calculate the current hour, minute, and second
hours   = seconds_today//seconds_in_an_hour
minutes = (seconds_today% seconds_in_an_hour )// 60
seconds = seconds_today%60


# Print the time in HH:MM:SS format
print(f"{hours:02}:{minutes:02}:{seconds:02}")
# Out:
# seconds_since_epoch=1765306710
# seconds_in_a_day=86400
# seconds_today=68310
# 18:58:30
